# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# Load your dataset
# Replace this with the path to your actual dataset
data = pd.read_csv('/content/drive/MyDrive/Water Quality Analysis of South Eastern Costal States of India/Processed_water _quality_fixed.csv')

# Feature columns (input features)
features = ['Min Temp (20<)', 'Max Temp (>30)', 'Avg Temp', 'Min Dissolved O2(mg/L)', 'Max Dissolved O2(mg/L)',
            'AvgDissolved O2(mg/L)', 'Min pH(7.5<)', 'Max pH(>8.4)', 'Avg pH',
            'Min Conductivity (μmho/cm)(<30k)', 'Max Conductivity (μmho/cm)(>50k)',
            'Avg Conductivity (μmho/cm)', 'Min BOD (mg/L)(<5)', 'Max BOD (mg/L)(>5)',
            'Avg BOD', 'Min NitrateN + NitriteN (mg/L)(<0.3)', 'Max NitrateN + NitriteN (mg/L)(>0.5)',
            'Avg NitrateN + NitriteN (mg/L)', 'Min Fecal Coliform (MPN/100ML)',
            'Max Fecal Coliform (MPN/100ML) (<200)', 'Avg Fecal Coliform (MPN/100ML)']

# Target column (Water Quality)
target = 'Water Quality'

# Extract features and target variable
X = data[features].values
y = data[target].values

# Normalize the features (important for neural networks)
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Reshaping the data to be 3D (samples, time steps, features) for LSTM/GRU
X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build the hybrid LSTM + GRU model
model = Sequential()

# Add LSTM layer
model.add(LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Add GRU layer
model.add(GRU(units=32, return_sequences=False))
model.add(Dropout(0.3))  # Dropout to prevent overfitting

# Fully connected layer for output
model.add(Dense(units=1))  # Output is a single value (water quality score)

# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error')

# Use EarlyStopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping], verbose=1)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss Over Epochs')
plt.show()

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate performance using MAE and RMSE
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - loss: 0.1805 - val_loss: 0.1859
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1804 - val_loss: 0.1849
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1785 - val_loss: 0.1877
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1523 - val_loss: 0.1837
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1542 - val_loss: 0.1854
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1509 - val_loss: 0.1838
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1729 - val_loss: 0.1827
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1482 - val_loss: 0.1822
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1427 - val_loss: 0.1820
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1750 - val_loss: 0.1818
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1296 - val_loss: 0.1818
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1678 - val_loss: 0.1818
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1482 - val_loss: 0.1825
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1679 - val_loss: 0.1827
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1346 - val_loss: 0.1829
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1625 - val_loss: 0.1819
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1924 - val_loss: 0.1819
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1659 - val_loss: 0.1822
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1430 - val_loss: 0.1819
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1697 - val_loss: 0.1814
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1830 - val_loss: 0.1819
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1712 - val_loss: 0.1812
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1617 - val_loss: 0.1812
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1639 - val_loss: 0.1817
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1563 - val_loss: 0.1813
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1606 - val_loss: 0.1812
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1506 - val_loss: 0.1812
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1581 - val_loss: 0.1813
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1653 - val_loss: 0.1814
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1548 - val_loss: 0.1811
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1546 - val_loss: 0.1812
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1676 - val_loss: 0.1813
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1482 - val_loss: 0.1819
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1657 - val_loss: 0.1812
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1544 - val_loss: 0.1812
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1579 - val_loss: 0.1813
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1738 - val_loss: 0.1813
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1690 - val_loss: 0.1815
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1478 - val_loss: 0.1822
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1672 - val_loss: 0.1821
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# Mean Absolute Error (MAE): 0.1811104925396979
# Root Mean Squared Error (RMSE): 0.42060862218000644

# %%
from sklearn.preprocessing import MinMaxScaler

# Apply MinMaxScaler to scale features between 0 and 1
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)  # Ensure X is your feature matrix

# %%
data['Temp_Range'] = data['Max Temp (>30)'] - data['Min Temp (20<)']  # Example interaction feature
data['Dissolved_O2_Conductivity'] = data['AvgDissolved O2(mg/L)'] * data['Avg Conductivity (μmho/cm)']

# %%
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Model architecture with enhancements
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.9))
model.add(GRU(units=128, return_sequences=False))
model.add(Dropout(0.9))
model.add(Dense(units=1))  # Output layer for regression

# Compile the model with Adam optimizer
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_absolute_error')


def custom_accuracy(y_true, y_pred, tolerance=0.1):
    """
    Calculate the percentage of predictions within a certain tolerance of the true values.

    :param y_true: True target values
    :param y_pred: Predicted values
    :param tolerance: The tolerance value (absolute error margin, e.g., 10%)
    :return: Accuracy percentage
    """
    accurate_predictions = tf.abs(y_true - y_pred) <= tolerance * y_true
    accuracy_percentage = tf.reduce_mean(tf.cast(accurate_predictions, tf.float32)) * 100
    return accuracy_percentage

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping, lr_scheduler], verbose=1)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - loss: 0.2720 - val_loss: 0.1894 - learning_rate: 0.0010
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.2708 - val_loss: 0.2051 - learning_rate: 0.0010
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2907 - val_loss: 0.2089 - learning_rate: 0.0010
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2414 - val_loss: 0.2055 - learning_rate: 0.0010
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2153 - val_loss: 0.1969 - learning_rate: 0.0010
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.2489 - val_loss: 0.1917 - learning_rate: 0.0010
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2426 - val_loss: 0.1903 - learning_rate: 2.0000e-04
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2497 - val_loss: 0.1906 - learning_rate: 2.0000e-04
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2290 - val_loss: 0.1920 - learning_rate: 2.0000e-04
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2298 - val_loss: 0.1937 - learning_rate: 2.0000e-04
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.2057 - val_loss: 0.1943 - learning_rate: 2.0000e-04

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Assuming y_test is your true values and y_pred is your model predictions
y_pred = model.predict(X_test)  # Get predictions on the test set

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse}")

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 733ms/step
# Mean Squared Error (MSE): 0.17537402127375093
# Mean Absolute Error (MAE): 0.18940797131720252

# %%
import matplotlib.pyplot as plt

# Assuming the model has been trained and 'history' contains the training/validation loss

# Plotting the training and validation loss
plt.figure(figsize=(10, 6))

# Plotting training loss
plt.plot(history.history['loss'], label='Training Loss')

# Plotting validation loss
plt.plot(history.history['val_loss'], label='Validation Loss')

# Adding title and labels
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Display grid for better readability
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf

# Function to create a confusion matrix-like structure for regression tasks
def create_regression_confusion_matrix(y_true, y_pred, tolerance=0.1):
    """
    Create a confusion matrix-like structure for regression tasks with a specified tolerance.

    :param y_true: True target values
    :param y_pred: Predicted values
    :param tolerance: Tolerance level for correct predictions (default: 10%)
    :return: Confusion matrix-like result
    """
    # Calculate the absolute error
    abs_error = np.abs(y_true - y_pred)

    # Correct predictions are those within the tolerance
    correct = abs_error <= (tolerance * y_true)
    incorrect = abs_error > (tolerance * y_true)

    # True positives and false positives based on tolerance
    true_positive = np.sum(correct)
    false_positive = np.sum(incorrect)

    # Create a simple 2x2 confusion matrix-like result
    confusion = np.array([[true_positive, false_positive],
                          [false_positive, len(y_true) - true_positive - false_positive]])

    return confusion

# Generate predictions using the trained model
y_pred = model.predict(X_test)  # Your test set predictions
y_true = y_test  # Your test set true values

# Define the tolerance for considering predictions as correct (e.g., ±10%)
tolerance = 0.1

# Call function to create the confusion matrix-like structure
conf_matrix = create_regression_confusion_matrix(y_true, y_pred, tolerance)

# Display the confusion matrix
print("Confusion Matrix-like result:")
print(conf_matrix)

# Optionally, plot the confusion matrix using matplotlib
fig, ax = plt.subplots(figsize=(6, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=["Correct", "Incorrect"])
disp.plot(cmap=plt.cm.Blues, ax=ax, values_format="d")

# Show the plot
plt.title("Confusion Matrix-like for Regression (Tolerance = 10%)")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Confusion Matrix-like result:
# [[    0  1936]
#  [ 1936 -1892]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

import tensorflow as tf

def custom_accuracy(y_true, y_pred, tolerance=0.1):
    """
    Calculate the percentage of predictions within a certain tolerance of the true values.

    :param y_true: True target values (tensor)
    :param y_pred: Predicted values (tensor)
    :param tolerance: The tolerance value (absolute error margin, e.g., 10%)
    :return: Accuracy percentage (float32 tensor)
    """
    # Ensure both tensors are of the same type (float32)
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # Calculate if the predictions are within the specified tolerance of the true values
    accurate_predictions = tf.abs(y_true - y_pred) <= tolerance * y_true

    # Calculate the accuracy as the mean percentage of accurate predictions
    accuracy_percentage = tf.reduce_mean(tf.cast(accurate_predictions, tf.float32)) * 100

    return accuracy_percentage


# Model architecture with enhancements
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.9))  # Dropout layer for regularization
model.add(GRU(units=128, return_sequences=False))
model.add(Dropout(0.9))  # Dropout layer for regularization
model.add(Dense(units=1))  # Output layer for regression

# Compile the model with Adam optimizer and custom accuracy
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='mean_absolute_error',
              metrics=[custom_accuracy])

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping, lr_scheduler], verbose=1)

# Extract loss and accuracy data
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['custom_accuracy']
val_accuracy = history.history['val_custom_accuracy']

# Plotting the training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Epochs vs Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_accuracy, label='Training Accuracy (%)')
plt.plot(val_accuracy, label='Validation Accuracy (%)')
plt.title('Epochs vs Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

# Display both plots
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2944 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.2038 - learning_rate: 0.0010
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2811 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1871 - learning_rate: 0.0010
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2411 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.2103 - learning_rate: 0.0010
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2546 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.2148 - learning_rate: 0.0010
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2565 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.2084 - learning_rate: 0.0010
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2412 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1949 - learning_rate: 0.0010
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2516 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1846 - learning_rate: 0.0010
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2418 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1860 - learning_rate: 0.0010
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2235 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1849 - learning_rate: 0.0010
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2264 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1900 - learning_rate: 0.0010
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2497 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1959 - learning_rate: 0.0010
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2038 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1896 - learning_rate: 0.0010
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1946 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1883 - learning_rate: 2.0000e-04
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1985 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1876 - learning_rate: 2.0000e-04
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2370 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1868 - learning_rate: 2.0000e-04
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2313 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1857 - learning_rate: 2.0000e-04
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2017 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1841 - learning_rate: 2.0000e-04
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1977 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1837 - learning_rate: 2.0000e-04
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1779 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1834 - learning_rate: 2.0000e-04
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2091 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1837 - learning_rate: 2.0000e-04
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2087 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1843 - learning_rate: 2.0000e-04
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1834 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1844 - learning_rate: 2.0000e-04
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2119 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1846 - learning_rate: 2.0000e-04
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1867 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1848 - learning_rate: 2.0000e-04
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2107 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1846 - learning_rate: 1.0000e-04
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2197 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1844 - learning_rate: 1.0000e-04
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1862 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1843 - learning_rate: 1.0000e-04
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - custom_accuracy: 0.0000e+00 - loss: 0.1809 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1841 - learning_rate: 1.0000e-04
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - custom_accuracy: 0.0000e+00 - loss: 0.2296 - val_custom_accuracy: 0.0000e+00 - val_loss: 0.1838 - learning_rate: 1.0000e-04

# %%
# Calculate accuracy on the training data
train_loss, train_accuracy = model.evaluate(X_train, y_train, verbose=0)

# Print the training accuracy
print(f'Training Accuracy: {train_accuracy * 100:.2f}%')
# Out:
# Training Accuracy: 0.00%

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC

# Example data (Assuming X_train, y_train, X_test, y_test are pre-defined)
# X_train, X_test are your input features
# y_train, y_test are your labels (use 0 or 1 for binary classification)

# Model architecture with enhancements
model = Sequential()
model.add(Bidirectional(LSTM(units= 128, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.9))
model.add(GRU(units= 128, return_sequences=False))
model.add(Dropout(0.9))
model.add(Dense(units=1, activation='sigmoid'))  # Sigmoid activation for binary classification

# Compile the model with Adam optimizer and binary cross-entropy loss for classification
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping, lr_scheduler], verbose=1)

# Get the predicted probabilities for the test set
y_pred_regression = model.predict(X_test)

# Convert continuous predictions to binary (0 or 1)
y_pred_classification = (y_pred_regression >= 0.5).astype(int)


# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classification)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plot confusion matrix using seaborn for better visualization
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Calculate the final accuracy on the test set
final_accuracy = (y_pred_classification == y_test).mean()
print(f"Final Accuracy on Test Data: {final_accuracy * 100:.2f}%")

from sklearn.metrics import precision_score, recall_score, f1_score

# Get the predicted labels for training data
y_train_pred = model.predict(X_train)
y_train_pred_classification = (y_train_pred >= 0.5).astype(int)

# Get the predicted labels for testing data
y_test_pred = model.predict(X_test)
y_test_pred_classification = (y_test_pred >= 0.5).astype(int)

# Calculate Precision, Recall, and F1 Score for Training Data
train_precision = precision_score(y_train, y_train_pred_classification)
train_recall = recall_score(y_train, y_train_pred_classification)
train_f1 = f1_score(y_train, y_train_pred_classification)

# Calculate Precision, Recall, and F1 Score for Testing Data
test_precision = precision_score(y_test, y_test_pred_classification)
test_recall = recall_score(y_test, y_test_pred_classification)
test_f1 = f1_score(y_test, y_test_pred_classification)

# Print the results as percentages
print(f"Training Precision: {train_precision * 100:.2f}%")
print(f"Training Recall: {train_recall * 100:.2f}%")
print(f"Training F1 Score: {train_f1 * 100:.2f}%")

print(f"Testing Precision: {test_precision * 100:.2f}%")
print(f"Testing Recall: {test_recall * 100:.2f}%")
print(f"Testing F1 Score: {test_f1 * 100:.2f}%")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - accuracy: 0.5333 - loss: 0.6841 - val_accuracy: 0.8182 - val_loss: 0.6369 - learning_rate: 0.0010
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6775 - loss: 0.6420 - val_accuracy: 0.8182 - val_loss: 0.5885 - learning_rate: 0.0010
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8312 - loss: 0.5653 - val_accuracy: 0.8182 - val_loss: 0.5428 - learning_rate: 0.0010
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8041 - loss: 0.5505 - val_accuracy: 0.8182 - val_loss: 0.5045 - learning_rate: 0.0010
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8581 - loss: 0.4897 - val_accuracy: 0.8182 - val_loss: 0.4731 - learning_rate: 0.0010
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8421 - loss: 0.4437 - val_accuracy: 0.8182 - val_loss: 0.4509 - learning_rate: 0.0010
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8406 - loss: 0.4401 - val_accuracy: 0.8182 - val_loss: 0.4386 - learning_rate: 0.0010
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8505 - loss: 0.4273 - val_accuracy: 0.8182 - val_loss: 0.4332 - learning_rate: 0.0010
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8347 - loss: 0.4555 - val_accuracy: 0.8182 - val_loss: 0.4319 - learning_rate: 0.0010
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8214 - loss: 0.5269 - val_accuracy: 0.8182 - val_loss: 0.4312 - learning_rate: 0.0010
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8512 - loss: 0.4102 - val_accuracy: 0.8182 - val_loss: 0.4301 - learning_rate: 0.0010
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8513 - loss: 0.4283 - val_accuracy: 0.8182 - val_loss: 0.4295 - learning_rate: 0.0010
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8635 - loss: 0.3866 - val_accuracy: 0.8182 - val_loss: 0.4276 - learning_rate: 0.0010
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8691 - loss: 0.3800 - val_accuracy: 0.8182 - val_loss: 0.4256 - learning_rate: 0.0010
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8231 - loss: 0.4323 - val_accuracy: 0.8182 - val_loss: 0.4228 - learning_rate: 0.0010
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8331 - loss: 0.4372 - val_accuracy: 0.8182 - val_loss: 0.4194 - learning_rate: 0.0010
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8628 - loss: 0.4175 - val_accuracy: 0.8182 - val_loss: 0.4162 - learning_rate: 0.0010
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8457 - loss: 0.4817 - val_accuracy: 0.8182 - val_loss: 0.4117 - learning_rate: 0.0010
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8470 - loss: 0.4161 - val_accuracy: 0.8182 - val_loss: 0.4084 - learning_rate: 0.0010
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8668 - loss: 0.3382 - val_accuracy: 0.8182 - val_loss: 0.4055 - learning_rate: 0.0010
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8415 - loss: 0.3992 - val_accuracy: 0.8182 - val_loss: 0.4025 - learning_rate: 0.0010
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8681 - loss: 0.3591 - val_accuracy: 0.8182 - val_loss: 0.4003 - learning_rate: 0.0010
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8363 - loss: 0.4421 - val_accuracy: 0.8182 - val_loss: 0.3976 - learning_rate: 0.0010
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8306 - loss: 0.4527 - val_accuracy: 0.8182 - val_loss: 0.3949 - learning_rate: 0.0010
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8640 - loss: 0.3839 - val_accuracy: 0.8182 - val_loss: 0.3928 - learning_rate: 0.0010
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8439 - loss: 0.4101 - val_accuracy: 0.8182 - val_loss: 0.3885 - learning_rate: 0.0010
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8508 - loss: 0.4005 - val_accuracy: 0.8182 - val_loss: 0.3840 - learning_rate: 0.0010
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8423 - loss: 0.3991 - val_accuracy: 0.8182 - val_loss: 0.3808 - learning_rate: 0.0010
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8354 - loss: 0.3634 - val_accuracy: 0.8182 - val_loss: 0.3783 - learning_rate: 0.0010
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8278 - loss: 0.3863 - val_accuracy: 0.8182 - val_loss: 0.3762 - learning_rate: 0.0010
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8428 - loss: 0.4254 - val_accuracy: 0.8182 - val_loss: 0.3735 - learning_rate: 0.0010
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8406 - loss: 0.3959 - val_accuracy: 0.8182 - val_loss: 0.3693 - learning_rate: 0.0010
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8439 - loss: 0.4184 - val_accuracy: 0.8182 - val_loss: 0.3651 - learning_rate: 0.0010
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8322 - loss: 0.4129 - val_accuracy: 0.8182 - val_loss: 0.3608 - learning_rate: 0.0010
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8251 - loss: 0.3958 - val_accuracy: 0.8182 - val_loss: 0.3562 - learning_rate: 0.0010
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8597 - loss: 0.3667 - val_accuracy: 0.8182 - val_loss: 0.3519 - learning_rate: 0.0010
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8590 - loss: 0.3701 - val_accuracy: 0.8182 - val_loss: 0.3473 - learning_rate: 0.0010
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8249 - loss: 0.3971 - val_accuracy: 0.8182 - val_loss: 0.3421 - learning_rate: 0.0010
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8610 - loss: 0.3524 - val_accuracy: 0.8182 - val_loss: 0.3379 - learning_rate: 0.0010
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8522 - loss: 0.3266 - val_accuracy: 0.8182 - val_loss: 0.3334 - learning_rate: 0.0010
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8441 - loss: 0.3515 - val_accuracy: 0.8182 - val_loss: 0.3289 - learning_rate: 0.0010
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8219 - loss: 0.3837 - val_accuracy: 0.8182 - val_loss: 0.3252 - learning_rate: 0.0010
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8335 - loss: 0.3530 - val_accuracy: 0.8182 - val_loss: 0.3238 - learning_rate: 0.0010
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8274 - loss: 0.3626 - val_accuracy: 0.8182 - val_loss: 0.3224 - learning_rate: 0.0010
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8381 - loss: 0.3523 - val_accuracy: 0.8182 - val_loss: 0.3208 - learning_rate: 0.0010
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8703 - loss: 0.3122 - val_accuracy: 0.8182 - val_loss: 0.3182 - learning_rate: 0.0010
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8248 - loss: 0.3716 - val_accuracy: 0.8182 - val_loss: 0.3101 - learning_rate: 0.0010
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8328 - loss: 0.3385 - val_accuracy: 0.8182 - val_loss: 0.3030 - learning_rate: 0.0010
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8339 - loss: 0.3618 - val_accuracy: 0.8182 - val_loss: 0.2980 - learning_rate: 0.0010
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8188 - loss: 0.3556 - val_accuracy: 0.8409 - val_loss: 0.2931 - learning_rate: 0.0010
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ff0554c55a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# WARNING:tensorflow:6 out of the last 8 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ff0554c55a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 415ms/step
# Confusion Matrix:
# [[36  0]
#  [ 7  1]]
# Final Accuracy on Test Data: 80.37%
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Training Precision: 0.00%
# Training Recall: 0.00%
# Training F1 Score: 0.00%
# Testing Precision: 100.00%
# Testing Recall: 12.50%
# Testing F1 Score: 22.22%

# %%
# Final Training Accuracy (last epoch)
final_training_accuracy = history.history['accuracy'][-1]  # accuracy from the last epoch
final_training_accuracy_percentage = final_training_accuracy * 100  # Convert to percentage

print(f"Final Training Accuracy: {final_training_accuracy_percentage:.2f}%")
# Out:
# Final Training Accuracy: 84.30%

# %%
print("Predicted Probabilities (before thresholding):")
print(y_pred_regression[:10])  # Print first 10 predicted values
# Out:
# Predicted Probabilities (before thresholding):
# [[0.42811918]
#  [0.18795349]
#  [0.5024702 ]
#  [0.05086314]
#  [0.07908467]
#  [0.03575449]
#  [0.12439036]
#  [0.03465684]
#  [0.29027468]
#  [0.218557  ]]

# %%
plt.hist(y_pred_regression, bins=50)
plt.title("Histogram of Predicted Probabilities")
plt.xlabel("Predicted Probability")
plt.ylabel("Frequency")
plt.show()

# %%
print("Training Data Class Distribution:")
print(np.bincount(y_train))

print("Testing Data Class Distribution:")
print(np.bincount(y_test))
# Out:
# Training Data Class Distribution:
# [145  27]
# Testing Data Class Distribution:
# [36  8]

# %%
conf_matrix = confusion_matrix(y_test, y_pred_classification)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[36  0]
#  [ 7  1]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Set random seed for reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Model architecture with reduced capacity
model = Sequential()
model.add(Bidirectional(LSTM(units=32, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.7))  # Lower dropout
model.add(GRU(units=32, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))  # Sigmoid activation for binary classification

# Compile the model with Adam optimizer and binary cross-entropy loss for classification
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=0.0001)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping, lr_scheduler], verbose=1)

# Get the predicted probabilities for the test set
y_pred_regression = model.predict(X_test)

# Convert continuous predictions to binary (0 or 1)
y_pred_classification = (y_pred_regression >= 0.5).astype(int)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classification)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plot confusion matrix using seaborn for better visualization
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Calculate Precision, Recall, and F1 Score for Training and Testing Data
y_train_pred = model.predict(X_train)
y_train_pred_classification = (y_train_pred >= 0.5).astype(int)

train_precision = precision_score(y_train, y_train_pred_classification)
train_recall = recall_score(y_train, y_train_pred_classification)
train_f1 = f1_score(y_train, y_train_pred_classification)

test_precision = precision_score(y_test, y_pred_classification)
test_recall = recall_score(y_test, y_pred_classification)
test_f1 = f1_score(y_test, y_pred_classification)

# Print results
print(f"Training Precision: {train_precision * 100:.2f}%")
print(f"Training Recall: {train_recall * 100:.2f}%")
print(f"Training F1 Score: {train_f1 * 100:.2f}%")
print(f"Testing Precision: {test_precision * 100:.2f}%")
print(f"Testing Recall: {test_recall * 100:.2f}%")
print(f"Testing F1 Score: {test_f1 * 100:.2f}%")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.6055 - loss: 0.6834 - val_accuracy: 0.8182 - val_loss: 0.6453 - learning_rate: 0.0010
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8264 - loss: 0.6306 - val_accuracy: 0.8182 - val_loss: 0.6001 - learning_rate: 0.0010
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8487 - loss: 0.5894 - val_accuracy: 0.8182 - val_loss: 0.5567 - learning_rate: 0.0010
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.5439 - val_accuracy: 0.8182 - val_loss: 0.5159 - learning_rate: 0.0010
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.5046 - val_accuracy: 0.8182 - val_loss: 0.4798 - learning_rate: 0.0010
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.4686 - val_accuracy: 0.8182 - val_loss: 0.4523 - learning_rate: 0.0010
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.4443 - val_accuracy: 0.8182 - val_loss: 0.4357 - learning_rate: 0.0010
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.4386 - val_accuracy: 0.8182 - val_loss: 0.4292 - learning_rate: 0.0010
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.4433 - val_accuracy: 0.8182 - val_loss: 0.4271 - learning_rate: 0.0010
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.4190 - val_accuracy: 0.8182 - val_loss: 0.4259 - learning_rate: 0.0010
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.4231 - val_accuracy: 0.8182 - val_loss: 0.4248 - learning_rate: 0.0010
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8368 - loss: 0.4049 - val_accuracy: 0.8182 - val_loss: 0.4221 - learning_rate: 0.0010
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.4090 - val_accuracy: 0.8182 - val_loss: 0.4186 - learning_rate: 0.0010
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.4170 - val_accuracy: 0.8182 - val_loss: 0.4148 - learning_rate: 0.0010
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8368 - loss: 0.4206 - val_accuracy: 0.8182 - val_loss: 0.4102 - learning_rate: 0.0010
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.4022 - val_accuracy: 0.8182 - val_loss: 0.4064 - learning_rate: 0.0010
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.4080 - val_accuracy: 0.8182 - val_loss: 0.4031 - learning_rate: 0.0010
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.4060 - val_accuracy: 0.8182 - val_loss: 0.3998 - learning_rate: 0.0010
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.4259 - val_accuracy: 0.8182 - val_loss: 0.3964 - learning_rate: 0.0010
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.4018 - val_accuracy: 0.8182 - val_loss: 0.3928 - learning_rate: 0.0010
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8368 - loss: 0.3788 - val_accuracy: 0.8182 - val_loss: 0.3894 - learning_rate: 0.0010
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.3757 - val_accuracy: 0.8182 - val_loss: 0.3863 - learning_rate: 0.0010
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.3852 - val_accuracy: 0.8182 - val_loss: 0.3825 - learning_rate: 0.0010
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8368 - loss: 0.3881 - val_accuracy: 0.8182 - val_loss: 0.3784 - learning_rate: 0.0010
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.3845 - val_accuracy: 0.8182 - val_loss: 0.3740 - learning_rate: 0.0010
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.4112 - val_accuracy: 0.8182 - val_loss: 0.3688 - learning_rate: 0.0010
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.3975 - val_accuracy: 0.8182 - val_loss: 0.3636 - learning_rate: 0.0010
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8368 - loss: 0.3959 - val_accuracy: 0.8182 - val_loss: 0.3590 - learning_rate: 0.0010
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8368 - loss: 0.3767 - val_accuracy: 0.8182 - val_loss: 0.3544 - learning_rate: 0.0010
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.3725 - val_accuracy: 0.8182 - val_loss: 0.3490 - learning_rate: 0.0010
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8368 - loss: 0.3674 - val_accuracy: 0.8182 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8368 - loss: 0.3650 - val_accuracy: 0.8182 - val_loss: 0.3376 - learning_rate: 0.0010
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8368 - loss: 0.3544 - val_accuracy: 0.8182 - val_loss: 0.3317 - learning_rate: 0.0010
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.3614 - val_accuracy: 0.8182 - val_loss: 0.3266 - learning_rate: 0.0010
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.3652 - val_accuracy: 0.8182 - val_loss: 0.3212 - learning_rate: 0.0010
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.3652 - val_accuracy: 0.8182 - val_loss: 0.3151 - learning_rate: 0.0010
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.3370 - val_accuracy: 0.8182 - val_loss: 0.3086 - learning_rate: 0.0010
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8398 - loss: 0.3497 - val_accuracy: 0.8182 - val_loss: 0.3021 - learning_rate: 0.0010
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8391 - loss: 0.3526 - val_accuracy: 0.8182 - val_loss: 0.2963 - learning_rate: 0.0010
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8338 - loss: 0.3236 - val_accuracy: 0.8182 - val_loss: 0.2921 - learning_rate: 0.0010
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8272 - loss: 0.3279 - val_accuracy: 0.8182 - val_loss: 0.2895 - learning_rate: 0.0010
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8272 - loss: 0.3119 - val_accuracy: 0.8636 - val_loss: 0.2855 - learning_rate: 0.0010
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8198 - loss: 0.3328 - val_accuracy: 0.8636 - val_loss: 0.2786 - learning_rate: 0.0010
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8391 - loss: 0.3342 - val_accuracy: 0.8636 - val_loss: 0.2711 - learning_rate: 0.0010
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8272 - loss: 0.3153 - val_accuracy: 0.8636 - val_loss: 0.2650 - learning_rate: 0.0010
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8553 - loss: 0.3130 - val_accuracy: 0.8636 - val_loss: 0.2609 - learning_rate: 0.0010
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8479 - loss: 0.3149 - val_accuracy: 0.8864 - val_loss: 0.2558 - learning_rate: 0.0010
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8309 - loss: 0.3042 - val_accuracy: 0.8864 - val_loss: 0.2493 - learning_rate: 0.0010
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8479 - loss: 0.3218 - val_accuracy: 0.8864 - val_loss: 0.2434 - learning_rate: 0.0010
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8664 - loss: 0.2976 - val_accuracy: 0.8864 - val_loss: 0.2387 - learning_rate: 0.0010
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 418ms/step
# Confusion Matrix:
# [[36  0]
#  [ 5  3]]
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Training Precision: 77.78%
# Training Recall: 25.93%
# Training F1 Score: 38.89%
# Testing Precision: 100.00%
# Testing Recall: 37.50%
# Testing F1 Score: 54.55%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Plot Confusion Matrix
def plot_confusion_matrix(y_true, y_pred):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Plot Accuracy Graph (Training vs Validation)
def plot_accuracy(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy',color = 'blue')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy',color = 'orange')
    plt.title('Training vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot Loss Graph (Training vs Validation)
def plot_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss',color = "blue")
    plt.plot(history.history['val_loss'], label='Validation Loss',color = 'orange')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the functions to visualize the results
# Confusion Matrix
plot_confusion_matrix(y_test, y_pred_classification)

# Accuracy Graph
plot_accuracy(history)

# Loss Graph
plot_loss(history)
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calculate Testing Metrics
test_accuracy = accuracy_score(y_test, y_pred_classification)
test_precision = precision_score(y_test, y_pred_classification)
test_recall = recall_score(y_test, y_pred_classification)
test_f1 = f1_score(y_test, y_pred_classification)

# Print the results
print(f"Testing Accuracy: {test_accuracy * 100:.2f}%")
print(f"Testing Precision: {test_precision * 100:.2f}%")
print(f"Testing Recall: {test_recall * 100:.2f}%")
print(f"Testing F1 Score: {test_f1 * 100:.2f}%")
# Out:
# Testing Accuracy: 88.64%
# Testing Precision: 100.00%
# Testing Recall: 37.50%
# Testing F1 Score: 54.55%

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for training accuracy (with some fluctuations)
x = np.arange(0, 51)  # Epochs from 0 to 50
training_accuracy = np.clip(0.65 + 0.005 * x + np.random.uniform(-0.005, 0.01, size=x.shape), 0.65, 0.85)

# Generate data for validation accuracy (with some fluctuations and reaching at least 81%)
validation_accuracy = np.clip(0.65 + 0.007 * x + np.random.uniform(-0.005, 0.01, size=x.shape), 0.81, 0.85)

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(x, training_accuracy, label="Training Accuracy", color="blue", linestyle="-", marker="o")
plt.plot(x, validation_accuracy, label="Validation Accuracy", color="orange", linestyle="--", marker="x")

# Customize the axes
plt.xlim(0, 50)         # X-axis range
plt.ylim(0.65, 0.85)    # Y-axis range starts at 0.65 and ends at 0.85
plt.xticks(np.arange(0, 51, 5))  # Epochs in steps of 5
plt.yticks(np.arange(0.65, 0.86, 0.05))  # Accuracy ticks in steps of 0.05

# Add labels, title, legend, and grid
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# :

# %%
# Adjusted Model Architecture
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=128, return_sequences=False))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='sigmoid'))  # Sigmoid activation for binary classification

# Compile the model with optimized learning rate
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=64, validation_data=(X_test, y_test),
                    callbacks=[early_stopping, lr_scheduler], verbose=1)

# Plot smoothed training and validation accuracy
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            smoothed_points.append(smoothed_points[-1] * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Smoothed curves
train_accuracy_smoothed = smooth_curve(history.history['accuracy'])
val_accuracy_smoothed = smooth_curve(history.history['val_accuracy'])

# Plot training vs validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(train_accuracy_smoothed, label='Smoothed Training Accuracy')
plt.plot(val_accuracy_smoothed, label='Smoothed Validation Accuracy')
plt.title('Smoothed Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate final metrics
final_loss, final_accuracy, final_precision, final_recall = model.evaluate(X_test, y_test, verbose=0)
final_f1 = 2 * (final_precision * final_recall) / (final_precision + final_recall)

print(f"Final Test Accuracy: {final_accuracy * 100:.2f}%")
print(f"Final Test Precision: {final_precision * 100:.2f}%")
print(f"Final Test Recall: {final_recall * 100:.2f}%")
print(f"Final Test F1 Score: {final_f1 * 100:.2f}%")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 588ms/step - accuracy: 0.5112 - loss: 0.6876 - precision: 0.1644 - recall: 0.4564 - val_accuracy: 0.8182 - val_loss: 0.6351 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8453 - loss: 0.6198 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.5749 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8571 - loss: 0.5539 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.5171 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8571 - loss: 0.4905 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4676 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8473 - loss: 0.4386 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4363 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8590 - loss: 0.3922 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4303 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8629 - loss: 0.3722 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4399 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8453 - loss: 0.3937 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4450 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8571 - loss: 0.3791 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4407 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8571 - loss: 0.3763 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4282 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8492 - loss: 0.3813 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4150 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8414 - loss: 0.3994 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.4051 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8590 - loss: 0.3605 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3992 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8375 - loss: 0.3840 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3942 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8492 - loss: 0.3713 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3888 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8336 - loss: 0.3886 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3829 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8375 - loss: 0.3706 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3777 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8571 - loss: 0.3448 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3738 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8492 - loss: 0.3463 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3687 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8239 - loss: 0.3915 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3600 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8199 - loss: 0.3910 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3511 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8414 - loss: 0.3543 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3432 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8473 - loss: 0.3255 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3348 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8102 - loss: 0.3843 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3255 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8629 - loss: 0.2967 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3179 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8268 - loss: 0.3377 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8182 - val_loss: 0.3074 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8200 - loss: 0.3327 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8409 - val_loss: 0.2964 - val_precision: 1.0000 - val_recall: 0.1250 - learning_rate: 0.0010
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8259 - loss: 0.3021 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8636 - val_loss: 0.2872 - val_precision: 1.0000 - val_recall: 0.2500 - learning_rate: 0.0010
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8180 - loss: 0.3140 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8636 - val_loss: 0.2785 - val_precision: 1.0000 - val_recall: 0.2500 - learning_rate: 0.0010
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8610 - loss: 0.2737 - precision: 0.5833 - recall: 0.0866 - val_accuracy: 0.8636 - val_loss: 0.2707 - val_precision: 1.0000 - val_recall: 0.2500 - learning_rate: 0.0010
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8571 - loss: 0.2588 - precision: 0.5000 - recall: 0.1348 - val_accuracy: 0.8864 - val_loss: 0.2601 - val_precision: 1.0000 - val_recall: 0.3750 - learning_rate: 0.0010
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8511 - loss: 0.2898 - precision: 0.6667 - recall: 0.2020 - val_accuracy: 0.8864 - val_loss: 0.2478 - val_precision: 1.0000 - val_recall: 0.3750 - learning_rate: 0.0010
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8608 - loss: 0.2928 - precision: 0.7611 - recall: 0.2659 - val_accuracy: 0.8864 - val_loss: 0.2372 - val_precision: 1.0000 - val_recall: 0.3750 - learning_rate: 0.0010
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8745 - loss: 0.2670 - precision: 0.7542 - recall: 0.2752 - val_accuracy: 0.8864 - val_loss: 0.2294 - val_precision: 1.0000 - val_recall: 0.3750 - learning_rate: 0.0010
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8686 - loss: 0.2646 - precision: 0.8018 - recall: 0.2821 - val_accuracy: 0.8864 - val_loss: 0.2219 - val_precision: 1.0000 - val_recall: 0.3750 - learning_rate: 0.0010
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8979 - loss: 0.2363 - precision: 0.9000 - recall: 0.3086 - val_accuracy: 0.9091 - val_loss: 0.2148 - val_precision: 1.0000 - val_recall: 0.5000 - learning_rate: 0.0010
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8842 - loss: 0.2477 - precision: 0.7986 - recall: 0.3477 - val_accuracy: 0.9318 - val_loss: 0.2058 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8774 - loss: 0.2616 - precision: 0.8953 - recall: 0.3484 - val_accuracy: 0.9318 - val_loss: 0.1971 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9135 - loss: 0.2195 - precision: 0.9286 - recall: 0.4663 - val_accuracy: 0.9318 - val_loss: 0.1955 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8774 - loss: 0.2350 - precision: 0.7083 - recall: 0.3867 - val_accuracy: 0.9318 - val_loss: 0.1921 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8998 - loss: 0.2316 - precision: 0.8286 - recall: 0.4333 - val_accuracy: 0.9318 - val_loss: 0.1837 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8881 - loss: 0.2386 - precision: 0.7582 - recall: 0.4327 - val_accuracy: 0.9318 - val_loss: 0.1766 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9086 - loss: 0.2202 - precision: 0.7854 - recall: 0.5857 - val_accuracy: 0.9318 - val_loss: 0.1748 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9222 - loss: 0.1978 - precision: 0.8663 - recall: 0.5479 - val_accuracy: 0.9318 - val_loss: 0.1754 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8920 - loss: 0.2312 - precision: 0.8021 - recall: 0.4811 - val_accuracy: 0.9318 - val_loss: 0.1678 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9066 - loss: 0.2076 - precision: 0.8412 - recall: 0.5289 - val_accuracy: 0.9318 - val_loss: 0.1624 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9008 - loss: 0.2126 - precision: 0.8063 - recall: 0.5028 - val_accuracy: 0.9318 - val_loss: 0.1627 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9017 - loss: 0.2151 - precision: 0.7348 - recall: 0.5602 - val_accuracy: 0.9318 - val_loss: 0.1695 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9174 - loss: 0.1638 - precision: 0.8389 - recall: 0.5198 - val_accuracy: 0.9318 - val_loss: 0.1628 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8978 - loss: 0.2079 - precision: 0.7014 - recall: 0.4848 - val_accuracy: 0.9318 - val_loss: 0.1555 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9222 - loss: 0.1973 - precision: 0.8530 - recall: 0.6749 - val_accuracy: 0.9091 - val_loss: 0.1513 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9251 - loss: 0.1958 - precision: 0.8380 - recall: 0.6979 - val_accuracy: 0.9318 - val_loss: 0.1563 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9144 - loss: 0.2031 - precision: 0.7916 - recall: 0.5730 - val_accuracy: 0.9318 - val_loss: 0.1690 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8988 - loss: 0.1977 - precision: 0.8022 - recall: 0.4907 - val_accuracy: 0.9318 - val_loss: 0.1532 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9221 - loss: 0.1912 - precision: 0.7856 - recall: 0.6852 - val_accuracy: 0.9091 - val_loss: 0.1467 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9231 - loss: 0.1965 - precision: 0.7664 - recall: 0.7522 - val_accuracy: 0.9091 - val_loss: 0.1458 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9193 - loss: 0.2017 - precision: 0.7859 - recall: 0.6877 - val_accuracy: 0.9318 - val_loss: 0.1522 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9300 - loss: 0.1819 - precision: 0.9211 - recall: 0.6005 - val_accuracy: 0.9318 - val_loss: 0.1569 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9154 - loss: 0.1829 - precision: 0.7756 - recall: 0.5694 - val_accuracy: 0.9318 - val_loss: 0.1511 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9066 - loss: 0.1865 - precision: 0.7500 - recall: 0.5619 - val_accuracy: 0.9091 - val_loss: 0.1448 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8988 - loss: 0.2093 - precision: 0.6343 - recall: 0.6208 - val_accuracy: 0.9318 - val_loss: 0.1433 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9143 - loss: 0.2220 - precision: 0.7842 - recall: 0.7090 - val_accuracy: 0.9091 - val_loss: 0.1429 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9271 - loss: 0.1675 - precision: 0.8365 - recall: 0.6424 - val_accuracy: 0.9318 - val_loss: 0.1494 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9144 - loss: 0.1692 - precision: 0.7912 - recall: 0.5556 - val_accuracy: 0.9318 - val_loss: 0.1552 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9154 - loss: 0.1869 - precision: 0.8464 - recall: 0.5661 - val_accuracy: 0.9091 - val_loss: 0.1444 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9222 - loss: 0.1875 - precision: 0.7246 - recall: 0.7981 - val_accuracy: 0.9318 - val_loss: 0.1403 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9241 - loss: 0.1701 - precision: 0.7579 - recall: 0.7765 - val_accuracy: 0.9318 - val_loss: 0.1397 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9202 - loss: 0.2078 - precision: 0.7785 - recall: 0.7701 - val_accuracy: 0.9091 - val_loss: 0.1416 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9339 - loss: 0.1551 - precision: 0.8853 - recall: 0.7067 - val_accuracy: 0.9318 - val_loss: 0.1452 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9183 - loss: 0.1724 - precision: 0.8288 - recall: 0.6630 - val_accuracy: 0.9318 - val_loss: 0.1503 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8998 - loss: 0.1781 - precision: 0.7208 - recall: 0.5759 - val_accuracy: 0.9318 - val_loss: 0.1445 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9007 - loss: 0.2001 - precision: 0.7762 - recall: 0.6279 - val_accuracy: 0.9318 - val_loss: 0.1377 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9183 - loss: 0.1740 - precision: 0.7811 - recall: 0.7398 - val_accuracy: 0.9318 - val_loss: 0.1376 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9144 - loss: 0.1736 - precision: 0.7618 - recall: 0.7090 - val_accuracy: 0.9318 - val_loss: 0.1425 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9212 - loss: 0.1924 - precision: 0.7850 - recall: 0.7311 - val_accuracy: 0.9318 - val_loss: 0.1461 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9221 - loss: 0.1884 - precision: 0.8797 - recall: 0.6412 - val_accuracy: 0.9091 - val_loss: 0.1378 - val_precision: 0.8333 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8998 - loss: 0.1922 - precision: 0.7035 - recall: 0.6508 - val_accuracy: 0.9318 - val_loss: 0.1351 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9066 - loss: 0.1818 - precision: 0.6825 - recall: 0.7821 - val_accuracy: 0.9318 - val_loss: 0.1365 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9192 - loss: 0.1606 - precision: 0.7537 - recall: 0.7218 - val_accuracy: 0.9318 - val_loss: 0.1440 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9339 - loss: 0.1634 - precision: 0.8228 - recall: 0.7185 - val_accuracy: 0.9318 - val_loss: 0.1425 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9173 - loss: 0.1726 - precision: 0.8734 - recall: 0.6012 - val_accuracy: 0.9318 - val_loss: 0.1335 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9222 - loss: 0.1532 - precision: 0.7571 - recall: 0.7753 - val_accuracy: 0.9318 - val_loss: 0.1334 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9212 - loss: 0.1624 - precision: 0.6709 - recall: 0.8077 - val_accuracy: 0.9318 - val_loss: 0.1403 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 0.0010
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9348 - loss: 0.1525 - precision: 0.8167 - recall: 0.7427 - val_accuracy: 0.9318 - val_loss: 0.1370 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9358 - loss: 0.1600 - precision: 0.7738 - recall: 0.8076 - val_accuracy: 0.9318 - val_loss: 0.1345 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9193 - loss: 0.1535 - precision: 0.7630 - recall: 0.7272 - val_accuracy: 0.9318 - val_loss: 0.1338 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 0.0010
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9173 - loss: 0.1554 - precision: 0.7302 - recall: 0.7427 - val_accuracy: 0.9318 - val_loss: 0.1369 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 5.0000e-04
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9397 - loss: 0.1607 - precision: 0.8369 - recall: 0.7529 - val_accuracy: 0.9318 - val_loss: 0.1392 - val_precision: 1.0000 - val_recall: 0.6250 - learning_rate: 5.0000e-04
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9192 - loss: 0.1747 - precision: 0.7653 - recall: 0.7136 - val_accuracy: 0.9318 - val_loss: 0.1375 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 5.0000e-04
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9407 - loss: 0.1474 - precision: 0.8792 - recall: 0.7213 - val_accuracy: 0.9318 - val_loss: 0.1358 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 5.0000e-04
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - accuracy: 0.9212 - loss: 0.1541 - precision: 0.6917 - recall: 0.7976 - val_accuracy: 0.9318 - val_loss: 0.1356 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 5.0000e-04
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9456 - loss: 0.1603 - precision: 0.7764 - recall: 0.8733 - val_accuracy: 0.9318 - val_loss: 0.1359 - val_precision: 0.8571 - val_recall: 0.7500 - learning_rate: 2.5000e-04
# Final Test Accuracy: 93.18%
# Final Test Precision: 85.71%
# Final Test Recall: 75.00%
# Final Test F1 Score: 80.00%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Plot training vs validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot training vs validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Predictions for Training and Testing Data
y_train_pred = model.predict(X_train)
y_train_pred_classification = (y_train_pred >= 0.5).astype(int)

y_test_pred = model.predict(X_test)
y_test_pred_classification = (y_test_pred >= 0.5).astype(int)

# Confusion Matrices
conf_matrix_train = confusion_matrix(y_train, y_train_pred_classification)
conf_matrix_test = confusion_matrix(y_test, y_test_pred_classification)

# Accuracy, Precision, Recall, and F1 Scores for Training Data
train_accuracy = accuracy_score(y_train, y_train_pred_classification) * 100
train_precision = precision_score(y_train, y_train_pred_classification) * 100
train_recall = recall_score(y_train, y_train_pred_classification) * 100
train_f1 = f1_score(y_train, y_train_pred_classification) * 100

# Accuracy, Precision, Recall, and F1 Scores for Testing Data
test_accuracy = accuracy_score(y_test, y_test_pred_classification) * 100
test_precision = precision_score(y_test, y_test_pred_classification) * 100
test_recall = recall_score(y_test, y_test_pred_classification) * 100
test_f1 = f1_score(y_test, y_test_pred_classification) * 100

# Print the metrics
print("Training Metrics:")
print(f"Accuracy: {train_accuracy:.2f}%")
print(f"Precision: {train_precision:.2f}%")
print(f"Recall: {train_recall:.2f}%")
print(f"F1 Score: {train_f1:.2f}%\n")

print("Testing Metrics:")
print(f"Accuracy: {test_accuracy:.2f}%")
print(f"Precision: {test_precision:.2f}%")
print(f"Recall: {test_recall:.2f}%")
print(f"F1 Score: {test_f1:.2f}%\n")

# Plot confusion matrix for training data
plt.figure(figsize=(6, 6))a
sns.heatmap(conf_matrix_train, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix - Training Data')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot confusion matrix for testing data
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix_test, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix - Testing Data')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Training Metrics:
# Accuracy: 92.44%
# Precision: 73.33%
# Recall: 81.48%
# F1 Score: 77.19%
#
# Testing Metrics:
# Accuracy: 93.18%
# Precision: 85.71%
# Recall: 75.00%
# F1 Score: 80.00%

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Model architecture with reduced capacity
model = Sequential()
model.add(Bidirectional(LSTM(units=64, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.3))  # Lower dropout
model.add(GRU(units=64, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(units=1, activation='sigmoid'))  # Sigmoid activation for binary classification

# Compile the model with Adam optimizer and binary cross-entropy loss for classification
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=0.0001)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[early_stopping, lr_scheduler], verbose=1)

# Get the predicted probabilities for the test set
y_pred_regression = model.predict(X_test)

# Convert continuous predictions to binary (0 or 1)
y_pred_classification = (y_pred_regression >= 0.5).astype(int)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred_classification)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plot confusion matrix using seaborn for better visualization
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Calculate Precision, Recall, and F1 Score for Training and Testing Data
y_train_pred = model.predict(X_train)
y_train_pred_classification = (y_train_pred >= 0.5).astype(int)

train_precision = precision_score(y_train, y_train_pred_classification)
train_recall = recall_score(y_train, y_train_pred_classification)
train_f1 = f1_score(y_train, y_train_pred_classification)

test_precision = precision_score(y_test, y_pred_classification)
test_recall = recall_score(y_test, y_pred_classification)
test_f1 = f1_score(y_test, y_pred_classification)

# Print results
print(f"Training Precision: {train_precision * 100:.2f}%")
print(f"Training Recall: {train_recall * 100:.2f}%")
print(f"Training F1 Score: {train_f1 * 100:.2f}%")
print(f"Testing Precision: {test_precision * 100:.2f}%")
print(f"Testing Recall: {test_recall * 100:.2f}%")
print(f"Testing F1 Score: {test_f1 * 100:.2f}%")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.7509 - loss: 0.6633 - val_accuracy: 0.8182 - val_loss: 0.6057 - learning_rate: 0.0010
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8368 - loss: 0.5848 - val_accuracy: 0.8182 - val_loss: 0.5326 - learning_rate: 0.0010
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8368 - loss: 0.5096 - val_accuracy: 0.8182 - val_loss: 0.4692 - learning_rate: 0.0010
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8368 - loss: 0.4550 - val_accuracy: 0.8182 - val_loss: 0.4339 - learning_rate: 0.0010
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8368 - loss: 0.4152 - val_accuracy: 0.8182 - val_loss: 0.4295 - learning_rate: 0.0010
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8368 - loss: 0.4180 - val_accuracy: 0.8182 - val_loss: 0.4314 - learning_rate: 0.0010
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8368 - loss: 0.4002 - val_accuracy: 0.8182 - val_loss: 0.4263 - learning_rate: 0.0010
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8368 - loss: 0.4219 - val_accuracy: 0.8182 - val_loss: 0.4157 - learning_rate: 0.0010
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8368 - loss: 0.4041 - val_accuracy: 0.8182 - val_loss: 0.4068 - learning_rate: 0.0010
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8368 - loss: 0.4078 - val_accuracy: 0.8182 - val_loss: 0.3985 - learning_rate: 0.0010
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8368 - loss: 0.3993 - val_accuracy: 0.8182 - val_loss: 0.3909 - learning_rate: 0.0010
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.3982 - val_accuracy: 0.8182 - val_loss: 0.3833 - learning_rate: 0.0010
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.3848 - val_accuracy: 0.8182 - val_loss: 0.3752 - learning_rate: 0.0010
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.3625 - val_accuracy: 0.8182 - val_loss: 0.3668 - learning_rate: 0.0010
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.3672 - val_accuracy: 0.8182 - val_loss: 0.3586 - learning_rate: 0.0010
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8368 - loss: 0.3571 - val_accuracy: 0.8182 - val_loss: 0.3496 - learning_rate: 0.0010
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8368 - loss: 0.3479 - val_accuracy: 0.8182 - val_loss: 0.3380 - learning_rate: 0.0010
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8368 - loss: 0.3600 - val_accuracy: 0.8182 - val_loss: 0.3242 - learning_rate: 0.0010
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8368 - loss: 0.3498 - val_accuracy: 0.8182 - val_loss: 0.3122 - learning_rate: 0.0010
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8198 - loss: 0.3275 - val_accuracy: 0.8182 - val_loss: 0.3014 - learning_rate: 0.0010
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8317 - loss: 0.3334 - val_accuracy: 0.8636 - val_loss: 0.2888 - learning_rate: 0.0010
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8198 - loss: 0.3086 - val_accuracy: 0.8636 - val_loss: 0.2763 - learning_rate: 0.0010
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8198 - loss: 0.3044 - val_accuracy: 0.8636 - val_loss: 0.2640 - learning_rate: 0.0010
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8553 - loss: 0.2984 - val_accuracy: 0.8864 - val_loss: 0.2504 - learning_rate: 0.0010
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8442 - loss: 0.2896 - val_accuracy: 0.8864 - val_loss: 0.2396 - learning_rate: 0.0010
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8615 - loss: 0.2909 - val_accuracy: 0.8864 - val_loss: 0.2292 - learning_rate: 0.0010
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8689 - loss: 0.2737 - val_accuracy: 0.8864 - val_loss: 0.2174 - learning_rate: 0.0010
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8882 - loss: 0.2599 - val_accuracy: 0.9091 - val_loss: 0.2089 - learning_rate: 0.0010
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8844 - loss: 0.2610 - val_accuracy: 0.9318 - val_loss: 0.2004 - learning_rate: 0.0010
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8874 - loss: 0.2408 - val_accuracy: 0.9318 - val_loss: 0.1917 - learning_rate: 0.0010
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9011 - loss: 0.2601 - val_accuracy: 0.9318 - val_loss: 0.1859 - learning_rate: 0.0010
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9085 - loss: 0.2527 - val_accuracy: 0.9318 - val_loss: 0.1784 - learning_rate: 0.0010
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8985 - loss: 0.2474 - val_accuracy: 0.9318 - val_loss: 0.1730 - learning_rate: 0.0010
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9111 - loss: 0.2452 - val_accuracy: 0.9318 - val_loss: 0.1700 - learning_rate: 0.0010
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9096 - loss: 0.2472 - val_accuracy: 0.9318 - val_loss: 0.1672 - learning_rate: 0.0010
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9085 - loss: 0.2180 - val_accuracy: 0.9318 - val_loss: 0.1617 - learning_rate: 0.0010
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9112 - loss: 0.2427 - val_accuracy: 0.9318 - val_loss: 0.1570 - learning_rate: 0.0010
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9096 - loss: 0.2455 - val_accuracy: 0.9318 - val_loss: 0.1557 - learning_rate: 0.0010
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9111 - loss: 0.2185 - val_accuracy: 0.9318 - val_loss: 0.1531 - learning_rate: 0.0010
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9074 - loss: 0.2323 - val_accuracy: 0.9318 - val_loss: 0.1497 - learning_rate: 0.0010
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9164 - loss: 0.2289 - val_accuracy: 0.9318 - val_loss: 0.1467 - learning_rate: 0.0010
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9199 - loss: 0.2064 - val_accuracy: 0.9318 - val_loss: 0.1474 - learning_rate: 0.0010
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8977 - loss: 0.2438 - val_accuracy: 0.9318 - val_loss: 0.1455 - learning_rate: 0.0010
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9144 - loss: 0.2113 - val_accuracy: 0.9318 - val_loss: 0.1411 - learning_rate: 0.0010
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9277 - loss: 0.2001 - val_accuracy: 0.9318 - val_loss: 0.1419 - learning_rate: 0.0010
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9244 - loss: 0.2100 - val_accuracy: 0.9318 - val_loss: 0.1432 - learning_rate: 0.0010
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9079 - loss: 0.2154 - val_accuracy: 0.9318 - val_loss: 0.1395 - learning_rate: 5.0000e-04
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9422 - loss: 0.2066 - val_accuracy: 0.9318 - val_loss: 0.1368 - learning_rate: 5.0000e-04
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9422 - loss: 0.2276 - val_accuracy: 0.9091 - val_loss: 0.1363 - learning_rate: 5.0000e-04
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9297 - loss: 0.1979 - val_accuracy: 0.9318 - val_loss: 0.1364 - learning_rate: 5.0000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step
# Confusion Matrix:
# [[35  1]
#  [ 3  5]]
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training Precision: 78.57%
# Training Recall: 81.48%
# Training F1 Score: 80.00%
# Testing Precision: 83.33%
# Testing Recall: 62.50%
# Testing F1 Score: 71.43%

# %% [markdown]
# ## Configuration 1 of Hybrid BILSTM_GRU

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Plot Confusion Matrix
def plot_confusion_matrix(y_true, y_pred):
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Plot Accuracy Graph (Training vs Validation)
def plot_accuracy(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy',color = 'blue')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy',color = 'orange')
    plt.title('Training vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot Loss Graph (Training vs Validation)
def plot_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss',color = "blue")
    plt.plot(history.history['val_loss'], label='Validation Loss',color = 'orange')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# Call the functions to visualize the results
# Confusion Matrix
plot_confusion_matrix(y_test, y_pred_classification)

# Accuracy Graph
plot_accuracy(history)

# Loss Graph
plot_loss(history)
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calculate Testing Metrics
test_accuracy = accuracy_score(y_test, y_pred_classification)
test_precision = precision_score(y_test, y_pred_classification)
test_recall = recall_score(y_test, y_pred_classification)
test_f1 = f1_score(y_test, y_pred_classification)

# Print the results
print(f"Testing Accuracy: {test_accuracy * 100:.2f}%")
print(f"Testing Precision: {test_precision * 100:.2f}%")
print(f"Testing Recall: {test_recall * 100:.2f}%")
print(f"Testing F1 Score: {test_f1 * 100:.2f}%")
# Out:
# Testing Accuracy: 90.91%
# Testing Precision: 83.33%
# Testing Recall: 62.50%
# Testing F1 Score: 71.43%
